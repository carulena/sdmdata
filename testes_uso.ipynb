# %%
from sdmdata.species_data import get_occurrences_by_key, get_species_autocomplete
import pandas as pd
from pygbif import species, occurrences
from tqdm import tqdm
from dotenv import load_dotenv
import os
import zipfile

load_dotenv()
# Out:
# True

# %%
get_species_autocomplete("Tetragonisca Ang")
# Out:
# [{'key': 1339480,
#   'nameKey': 11113331,
#   'kingdom': 'Animalia',
#   'phylum': 'Arthropoda',
#   'order': 'Hymenoptera',
#   'family': 'Apidae',
#   'genus': 'Tetragonisca',
#   'species': 'Tetragonisca angustula',
#   'kingdomKey': 1,
#   'phylumKey': 54,
#   'classKey': 216,
#   'orderKey': 1457,
#   'familyKey': 4334,
#   'genusKey': 1339479,
#   'speciesKey': 1339480,
#   'parent': 'Tetragonisca',
#   'parentKey': 1339479,
#   'nubKey': 1339480,
#   'scientificName': 'Tetragonisca angustula (Latreille, 1811)',
#   'canonicalName': 'Tetragonisca angustula',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'higherClassificationMap': {'1': 'Animalia',
#    '54': 'Arthropoda',
#    '216': 'Insecta',
#    '1457': 'Hymenoptera',
#    '4334': 'Apidae',
#    '1339479': 'Tetragonisca'},
#   'class': 'Insecta'}]
